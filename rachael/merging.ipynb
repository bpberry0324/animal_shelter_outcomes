# %% [markdown]
# merging intakes/outcomes

# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 100)

pd.set_option('display.max_rows', 100)

# %%
outcomes = pd.read_csv('../datasets/outcomes_initial.csv').drop(columns=['Unnamed: 0'])
intakes = pd.read_csv('../datasets/outcomes_initial.csv').drop(columns=['Unnamed: 0'])

# %%
outcomes.shape
# Out:
# (129432, 15)

# %%
intakes.shape
# Out:
# (129432, 15)

# %%
outcomes.head()
# Out:
#   animal_id   name             datetime date_of_birth outcome_type  \
# 0   A794011  Chunk  2019-05-08 18:20:00    05/02/2017    Rto-Adopt
# 1   A776359  Gizmo  2018-07-18 16:02:00    07/12/2017     Adoption
# 2   A821648    NaN  2020-08-16 11:38:00    08/16/2019   Euthanasia
# 3   A720371  Moose  2016-02-13 17:59:00    10/08/2015     Adoption
# 4   A674754    NaN  2014-03-18 11:47:00    03/12/2014     Transfer
#
#   outcome_subtype animal_type sex_upon_outcome  age_upon_outcome  \
# 0         Unknown         Cat    Neutered Male             2.000
# 1         Unknown         Dog    Neutered Male             1.000
# 2         Unknown       Other          Unknown             1.000
# 3         Unknown         Dog    Neutered Male             0.333
# 4         Partner         Cat      Intact Male             0.016
#
#                                 breed              color  is_named  year  \
# 0              Domestic Shorthair Mix  Brown Tabby/White         1  2019
# 1             Chihuahua Shorthair Mix        White/Brown         1  2018
# 2                             Raccoon               Gray         0  2020
# 3  Anatol Shepherd/Labrador Retriever               Buff         1  2016
# 4              Domestic Shorthair Mix       Orange Tabby         0  2014
#
#    month        day
# 0      5  Wednesday
# 1      7  Wednesday
# 2      8     Sunday
# 3      2   Saturday
# 4      3    Tuesday

# %%
intakes.head()
# Out:
#   animal_id   name             datetime date_of_birth outcome_type  \
# 0   A794011  Chunk  2019-05-08 18:20:00    05/02/2017    Rto-Adopt
# 1   A776359  Gizmo  2018-07-18 16:02:00    07/12/2017     Adoption
# 2   A821648    NaN  2020-08-16 11:38:00    08/16/2019   Euthanasia
# 3   A720371  Moose  2016-02-13 17:59:00    10/08/2015     Adoption
# 4   A674754    NaN  2014-03-18 11:47:00    03/12/2014     Transfer
#
#   outcome_subtype animal_type sex_upon_outcome  age_upon_outcome  \
# 0         Unknown         Cat    Neutered Male             2.000
# 1         Unknown         Dog    Neutered Male             1.000
# 2         Unknown       Other          Unknown             1.000
# 3         Unknown         Dog    Neutered Male             0.333
# 4         Partner         Cat      Intact Male             0.016
#
#                                 breed              color  is_named  year  \
# 0              Domestic Shorthair Mix  Brown Tabby/White         1  2019
# 1             Chihuahua Shorthair Mix        White/Brown         1  2018
# 2                             Raccoon               Gray         0  2020
# 3  Anatol Shepherd/Labrador Retriever               Buff         1  2016
# 4              Domestic Shorthair Mix       Orange Tabby         0  2014
#
#    month        day
# 0      5  Wednesday
# 1      7  Wednesday
# 2      8     Sunday
# 3      2   Saturday
# 4      3    Tuesday

# %%
intakes_val_counts = intakes['animal_id'].value_counts()

#count of animal ids that show up more than once in dataset
len(intakes_val_counts[intakes_val_counts>1])
# Out:
# 10489

# %%
outcomes_val_counts = outcomes['animal_id'].value_counts()

#count of animal ids that show up more than once in dataset
len(outcomes_val_counts[outcomes_val_counts>1])
# Out:
# 10489

# %%
intakes.sort_values(by='datetime', inplace=True)

# %%
outcomes.sort_values(by='datetime', inplace=True)

# %%
intakes_counts_dict = intakes['animal_id'].value_counts().to_dict()

# %%
len(intakes_counts_dict)
# Out:
# 115728

# %%
outcomes_counts_dict = outcomes['animal_id'].value_counts().to_dict()

# %%
len(outcomes_counts_dict)
# Out:
# 115728

# %%
intakes['frequency_animal_id'] = intakes['animal_id'].map(intakes_counts_dict)

# %%
intakes.head()
# Out:
#        animal_id     name             datetime date_of_birth     outcome_type  \
# 55919    A659834  *Dudley  2013-10-01 09:31:00    07/23/2013         Adoption
# 46051    A664235      NaN  2013-10-01 10:39:00    09/24/2013         Transfer
# 100440   A664237      NaN  2013-10-01 10:44:00    09/24/2013         Transfer
# 85107    A664236      NaN  2013-10-01 10:44:00    09/24/2013         Transfer
# 11064    A664223     Moby  2013-10-01 11:03:00    09/30/2009  Return to Owner
#
#        outcome_subtype animal_type sex_upon_outcome  age_upon_outcome  \
# 55919           Foster         Dog    Neutered Male             0.167
# 46051          Partner         Cat          Unknown             0.019
# 100440         Partner         Cat          Unknown             0.019
# 85107          Partner         Cat          Unknown             0.019
# 11064          Unknown         Dog    Neutered Male             4.000
#
#                          breed         color  is_named  year  month      day  \
# 55919   Labrador Retriever Mix         Black         1  2013     10  Tuesday
# 46051   Domestic Shorthair Mix  Orange/White         0  2013     10  Tuesday
# 100440  Domestic Shorthair Mix  Orange/White         0  2013     10  Tuesday
# 85107   Domestic Shorthair Mix  Orange/White         0  2013     10  Tuesday
# 11064              Bulldog Mix         White         1  2013     10  Tuesday
#
#         frequency_animal_id
# 55919                     1
# 46051                     1
# 100440                    1
# 85107                     1
# 11064                     1

# %%
outcomes['frequency_animal_id'] = outcomes['animal_id'].map(outcomes_counts_dict)

# %%
outcomes.head()
# Out:
#        animal_id     name             datetime date_of_birth     outcome_type  \
# 55919    A659834  *Dudley  2013-10-01 09:31:00    07/23/2013         Adoption
# 46051    A664235      NaN  2013-10-01 10:39:00    09/24/2013         Transfer
# 100440   A664237      NaN  2013-10-01 10:44:00    09/24/2013         Transfer
# 85107    A664236      NaN  2013-10-01 10:44:00    09/24/2013         Transfer
# 11064    A664223     Moby  2013-10-01 11:03:00    09/30/2009  Return to Owner
#
#        outcome_subtype animal_type sex_upon_outcome  age_upon_outcome  \
# 55919           Foster         Dog    Neutered Male             0.167
# 46051          Partner         Cat          Unknown             0.019
# 100440         Partner         Cat          Unknown             0.019
# 85107          Partner         Cat          Unknown             0.019
# 11064          Unknown         Dog    Neutered Male             4.000
#
#                          breed         color  is_named  year  month      day  \
# 55919   Labrador Retriever Mix         Black         1  2013     10  Tuesday
# 46051   Domestic Shorthair Mix  Orange/White         0  2013     10  Tuesday
# 100440  Domestic Shorthair Mix  Orange/White         0  2013     10  Tuesday
# 85107   Domestic Shorthair Mix  Orange/White         0  2013     10  Tuesday
# 11064              Bulldog Mix         White         1  2013     10  Tuesday
#
#         frequency_animal_id
# 55919                     1
# 46051                     1
# 100440                    1
# 85107                     1
# 11064                     1
