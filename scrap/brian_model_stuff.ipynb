# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/main.csv')

# %%
df.head()
# Out:
#   animal_id_in animal_type         color                        breed  \
# 0      A006100         Dog  yellow white         spinone italiano mix
# 1      A006100         Dog  yellow white         spinone italiano mix
# 2      A047759         Dog      tricolor                    dachshund
# 3      A134067         Dog   brown white            sheepdog shetland
# 4      A141142         Dog   white black  retriever labrador bull pit
#
#        intake_type     outcome_type intake_condition outcome_subtype  \
# 0    Public Assist  Return to Owner           Normal         Unknown
# 1    Public Assist  Return to Owner           Normal         Unknown
# 2  Owner Surrender         Transfer           Normal         Partner
# 3    Public Assist  Return to Owner          Injured         Unknown
# 4            Stray  Return to Owner             Aged         Unknown
#
#            datetime_in         datetime_out  ...  prev_relocate  \
# ...

# %%
(pd.to_datetime(df['datetime_out']) - pd.to_datetime(df['datetime_in'])).astype('int')/(10**9)
# Out:
# 0         108840.0
# 1          96240.0
# 2         429420.0
# 3          10320.0
# 4          75240.0
#             ...
# 127139      6480.0
# 127140      6480.0
# 127141      1860.0
# 127142     43500.0
# 127143     71280.0
# Length: 127144, dtype: float64

# %%
df = df[df['outcome_type'] == 'Adoption']

# %%
df.head()
# Out:
#    animal_id_in animal_type        color                      breed  \
# 12      A200922         Dog    tan black              mix dachshund
# 14      A210457         Dog    tan black        chihuahua shorthair
# 23      A226069         Dog  white sable  beagle labrador retriever
# 33      A249087         Dog  brown black        mix shepherd german
# 49      A274546         Dog     tricolor                mix pointer
#
#         intake_type outcome_type intake_condition outcome_subtype  \
# 12  Owner Surrender     Adoption           Normal          Foster
# 14    Public Assist     Adoption             Aged          Foster
# 23            Stray     Adoption           Normal          Foster
# 33            Stray     Adoption           Normal          Foster
# 49            Stray     Adoption           Normal         Unknown
#
#             datetime_in         datetime_out  ...  prev_relocate  \
# 12  2013-10-03 15:47:00  2013-11-22 09:44:00  ...              0
# ...

# %%
df.drop(columns=['animal_id_in', 'outcome_subtype', 'sex_upon_intake', 'found_location', 'name_in', 'name_out'], inplace = True)
# Out:
# /Users/brianberry/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    animal_type        color                      breed      intake_type  \
# 12         Dog    tan black              mix dachshund  Owner Surrender
# 14         Dog    tan black        chihuahua shorthair    Public Assist
# 23         Dog  white sable  beagle labrador retriever            Stray
# 33         Dog  brown black        mix shepherd german            Stray
# 49         Dog     tricolor                mix pointer            Stray
#
#    outcome_type intake_condition          datetime_in         datetime_out  \
# 12     Adoption           Normal  2013-10-03 15:47:00  2013-11-22 09:44:00
# 14     Adoption             Aged  2016-09-28 12:05:00  2016-10-07 12:34:00
# 23     Adoption           Normal  2015-10-06 12:29:00  2015-10-29 15:00:00
# 33     Adoption           Normal  2016-08-17 14:05:00  2016-11-15 10:37:00
# 49     Adoption           Normal  2013-11-13 18:16:00  2013-11-16 12:24:00
#
#     year_in  month_in  ... prev_ret_to_owner  prev_rto_adopt  prev_disposal  \
# ...

# %%
df.columns
# Out:
# Index(['animal_type', 'color', 'breed', 'intake_type', 'outcome_type',
#        'intake_condition', 'datetime_in', 'datetime_out', 'year_in',
#        'month_in', 'day_in', 'year_out', 'month_out', 'day_out',
#        'prev_adoption', 'prev_transfer', 'prev_ret_to_owner', 'prev_rto_adopt',
#        'prev_disposal', 'prev_missing', 'prev_relocate', 'age_upon_outcome',
#        'age_upon_intake', 'sex_upon_outcome', 'is_named_in', 'is_named_out'],
#       dtype='object')

# %%
df.drop(columns=['year_out', 'month_out', 'day_out'], inplace = True)
# Out:
# /Users/brianberry/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    animal_type        color                      breed      intake_type  \
# 12         Dog    tan black              mix dachshund  Owner Surrender
# 14         Dog    tan black        chihuahua shorthair    Public Assist
# 23         Dog  white sable  beagle labrador retriever            Stray
# 33         Dog  brown black        mix shepherd german            Stray
# 49         Dog     tricolor                mix pointer            Stray
#
#    outcome_type intake_condition          datetime_in         datetime_out  \
# 12     Adoption           Normal  2013-10-03 15:47:00  2013-11-22 09:44:00
# 14     Adoption             Aged  2016-09-28 12:05:00  2016-10-07 12:34:00
# 23     Adoption           Normal  2015-10-06 12:29:00  2015-10-29 15:00:00
# 33     Adoption           Normal  2016-08-17 14:05:00  2016-11-15 10:37:00
# 49     Adoption           Normal  2013-11-13 18:16:00  2013-11-16 12:24:00
#
#     year_in  month_in  ... prev_ret_to_owner  prev_rto_adopt  prev_disposal  \
# ...

# %%
df.columns
# Out:
# Index(['animal_type', 'color', 'breed', 'intake_type', 'outcome_type',
#        'intake_condition', 'datetime_in', 'datetime_out', 'year_in',
#        'month_in', 'day_in', 'prev_adoption', 'prev_transfer',
#        'prev_ret_to_owner', 'prev_rto_adopt', 'prev_disposal', 'prev_missing',
#        'prev_relocate', 'age_upon_outcome', 'age_upon_intake',
#        'sex_upon_outcome', 'is_named_in', 'is_named_out'],
#       dtype='object')

# %%
df.drop(columns=['age_upon_intake'], inplace = True)
# Out:
# /Users/brianberry/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    animal_type        color                      breed      intake_type  \
# 12         Dog    tan black              mix dachshund  Owner Surrender
# 14         Dog    tan black        chihuahua shorthair    Public Assist
# 23         Dog  white sable  beagle labrador retriever            Stray
# 33         Dog  brown black        mix shepherd german            Stray
# 49         Dog     tricolor                mix pointer            Stray
#
#    outcome_type intake_condition          datetime_in         datetime_out  \
# 12     Adoption           Normal  2013-10-03 15:47:00  2013-11-22 09:44:00
# 14     Adoption             Aged  2016-09-28 12:05:00  2016-10-07 12:34:00
# 23     Adoption           Normal  2015-10-06 12:29:00  2015-10-29 15:00:00
# 33     Adoption           Normal  2016-08-17 14:05:00  2016-11-15 10:37:00
# 49     Adoption           Normal  2013-11-13 18:16:00  2013-11-16 12:24:00
#
#     year_in  month_in  ... prev_transfer  prev_ret_to_owner  prev_rto_adopt  \
# ...

# %%
df['duration'] = (pd.to_datetime(df['datetime_out']) - pd.to_datetime(df['datetime_in'])).dt.total_seconds()
# Out:
# <ipython-input-37-f58424d9a503>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration'] = (pd.to_datetime(df['datetime_out']) - pd.to_datetime(df['datetime_in'])).dt.total_seconds()

# %%
df.head()
# Out:
#    animal_type        color                      breed      intake_type  \
# 12         Dog    tan black              mix dachshund  Owner Surrender
# 14         Dog    tan black        chihuahua shorthair    Public Assist
# 23         Dog  white sable  beagle labrador retriever            Stray
# 33         Dog  brown black        mix shepherd german            Stray
# 49         Dog     tricolor                mix pointer            Stray
#
#    outcome_type intake_condition          datetime_in         datetime_out  \
# 12     Adoption           Normal  2013-10-03 15:47:00  2013-11-22 09:44:00
# 14     Adoption             Aged  2016-09-28 12:05:00  2016-10-07 12:34:00
# 23     Adoption           Normal  2015-10-06 12:29:00  2015-10-29 15:00:00
# 33     Adoption           Normal  2016-08-17 14:05:00  2016-11-15 10:37:00
# 49     Adoption           Normal  2013-11-13 18:16:00  2013-11-16 12:24:00
#
#     year_in  month_in  ... prev_ret_to_owner  prev_rto_adopt  prev_disposal  \
# ...

# %%
df.drop(columns=['datetime_in', 'datetime_out'], inplace=True)
# Out:
# /Users/brianberry/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    animal_type        color                      breed      intake_type  \
# 12         Dog    tan black              mix dachshund  Owner Surrender
# 14         Dog    tan black        chihuahua shorthair    Public Assist
# 23         Dog  white sable  beagle labrador retriever            Stray
# 33         Dog  brown black        mix shepherd german            Stray
# 49         Dog     tricolor                mix pointer            Stray
#
#    outcome_type intake_condition  year_in  month_in     day_in  prev_adoption  \
# 12     Adoption           Normal     2013        10   Thursday              0
# 14     Adoption             Aged     2016         9  Wednesday              0
# 23     Adoption           Normal     2015        10    Tuesday              0
# 33     Adoption           Normal     2016         8  Wednesday              0
# 49     Adoption           Normal     2013        11  Wednesday              0
#
# ...

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['animal_type'], prefix='animal_type', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['animal_type'], inplace=True)

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['color'], prefix='color', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['color'], inplace=True)

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['breed'], prefix='breed', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['breed'], inplace=True)

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['intake_type'], prefix='intake_type', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['intake_type'], inplace=True)

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['intake_condition'], prefix='intake_condition', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['intake_condition'], inplace=True)

# %%
df.drop(columns=['year_in'], inplace=True)

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['day_in'], prefix='day_in', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['day_in'], inplace=True)

# %%
df.drop(columns=['outcome_type'], inplace=True)

# %%
df = pd.merge(left=df, right=pd.get_dummies(df['sex_upon_outcome'], prefix='sex_upon_outcome', drop_first=True), how='inner', 
         left_index = True, right_index = True)

# %%
df.drop(columns=['sex_upon_outcome'], inplace=True)

# %%
import numpy as np
from sklearn.datasets import make_classification, make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
df.head()
# Out:
#     month_in  prev_adoption  prev_transfer  prev_ret_to_owner  prev_rto_adopt  \
# 12        10              0              0                  0               0
# 14         9              0              0                  0               0
# 23        10              0              0                  0               0
# 33         8              0              0                  0               0
# 49        11              0              0                  0               0
#
#     prev_disposal  prev_missing  prev_relocate  age_upon_outcome  is_named_in  \
# 12              0             0              0               1.0            1
# 14              0             0              0               1.0            1
# 23              0             0              0               1.0            1
# 33              0             0              0               1.0            1
# 49              0             0              0               1.0            1
#
# ...

# %%
X = df.drop(columns=['duration'])
y = df['duration']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

sc = StandardScaler()

X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
X_train_sc.shape
# Out:
# (42837, 1915)

# %%
model = Sequential()

model.add(Dense(64,
                input_shape=(X_train_sc.shape[1],),
                activation='relu'
         ))

model.add(Dense(64, 
                activation='relu'))

model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# %%
model.fit(X_train_sc, y_train, validation_data=(X_test_sc, y_test), 
          epochs=140, batch_size=512);
# Out:
# Epoch 1/140
# 84/84 [==============================] - 1s 5ms/step - loss: 34902980427776.0000 - mse: 34902980427776.0000 - val_loss: 32157848305664.0000 - val_mse: 32157848305664.0000
# Epoch 2/140
# 84/84 [==============================] - 0s 4ms/step - loss: 34900694532096.0000 - mse: 34900694532096.0000 - val_loss: 32152821432320.0000 - val_mse: 32152821432320.0000
# Epoch 3/140
# 84/84 [==============================] - 0s 4ms/step - loss: 34890504470528.0000 - mse: 34890504470528.0000 - val_loss: 32136474132480.0000 - val_mse: 32136474132480.0000
# Epoch 4/140
# 84/84 [==============================] - 0s 4ms/step - loss: 34865269440512.0000 - mse: 34865269440512.0000 - val_loss: 32102158434304.0000 - val_mse: 32102158434304.0000
# Epoch 5/140
# 84/84 [==============================] - 0s 4ms/step - loss: 34818473590784.0000 - mse: 34818473590784.0000 - val_loss: 32043553521664.0000 - val_mse: 32043553521664.0000
# Epoch 6/140
# ...

# %%
model.evaluate(X_test_sc, y_test, batch_size=512)
# Out:
# 28/28 [==============================] - 0s 2ms/step - loss: 22411982405632.0000 - mse: 22411982405632.0000
# [22411982405632.0, 22411982405632.0]

# %%
df['duration'].mean()
# Out:
# 2815627.8314307723

# %%
22411982405632**0.5
# Out:
# 4734129.529874737
